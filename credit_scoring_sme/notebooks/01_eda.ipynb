# %% [markdown]
# # Exploratory Data Analysis
# ## Alternative Credit Scoring for SMEs

# %%
import sys
import os

# Add src to path
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

from src.data.loader import DataLoader
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
loader = DataLoader()
df_trans, df_ads, df_loans = loader.load_all()

# %% [markdown]
# ### 1. Transactions Data

# %%
print("Shape:", df_trans.shape)
display(df_trans.head())
df_trans.info()

# %%
# Transaction Types Distribution
sns.countplot(x='transaction_type', data=df_trans)
plt.title('Transaction Types')

# %% [markdown]
# ### 2. Ad Spend Data

# %%
print("Shape:", df_ads.shape)
display(df_ads.head())

# %%
# ROI Calculation (basic proxy)
df_ads['cpc'] = df_ads['spend_amount'] / df_ads['clicks']
df_ads['cpc'].hist(bins=20)
plt.title('Cost Per Click Distribution')

# %% [markdown]
# ### 3. Loan Performance (Target)

# %%
print("Shape:", df_loans.shape)
display(df_loans.head())
print(df_loans['status'].value_counts(normalize=True))
